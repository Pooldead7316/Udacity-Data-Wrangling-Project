# %% [markdown]
# <a href="https://colab.research.google.com/github/Pooldead7316/Udacity-Data-Wrangling-Project/blob/main/Tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-da6a92eb-765c-48a3-acc9-6c08d0b3590c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-da6a92eb-765c-48a3-acc9-6c08d0b3590c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data = pd.read_csv("Parks_and_green_spaces.csv")
data.head(5)
# Out:
#    OBJECTID    ASSET_ID                               SITE_NAME  PLOT_NO  \
# 0         1  PK00144904  Horfield Common Tennis Centre (Ardagh)   108888
# 1         2  PK00145098                                The Tump   108888
# 2         3  PK00145035           Rowlandson Gardens Open Space   108888
# 3         4  PK00144896                          Highridge Park   108888
# 4         5  PK00144849      Frenchay Park Road (Stapleton AFC)   108888
#
#       FEATURE_ID             LOCATION                        TYPE  PRIM_MEAS  \
# 0     Local Park   Sports Facilities,  Parks and Green Space Site        1.0
# 1     Open Space                  NaN  Parks and Green Space Site        1.0
# 2     Open Space                  NaN  Parks and Green Space Site        1.0
# 3     Open Space                  NaN  Parks and Green Space Site        1.0
# 4  Playing Field   Sports Facilities,  Parks and Green Space Site        1.0
#
# ...

# %%
data.columns
# Out:
# Index(['OBJECTID', 'ASSET_ID', 'SITE_NAME', 'PLOT_NO', 'FEATURE_ID',
#        'LOCATION', 'TYPE', 'PRIM_MEAS', 'UNIT', 'SITE_CODE', 'FEAT_GP', 'UPRN',
#        'VALIDATED', 'CENTROID_X', 'CENTROID_Y', 'FEATURE_AREA',
#        'FEATURE_LENGTH', 'WEB_SITE', 'MAKE_UPRN', 'MAJOR_SITE',
#        'CENTRAL_ASSET_ID', 'CONTRACT_AREA_NAME', 'CUSTOMER', 'DEAD_FLAG',
#        'FEATURE_GROUP', 'FEATURE_GROUP_CODE', 'FEATURE_TYPE_NAME',
#        'FEATURETYPECODE', 'NOTES', 'REVISION_NO',
#        'gislive.PARKS.P_AND_GS_SITES.AREA', 'SITE', 'SHAPESTArea',
#        'SHAPESTLength'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 416 entries, 0 to 415
# Data columns (total 34 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   OBJECTID                           416 non-null    int64
#  1   ASSET_ID                           416 non-null    object
#  2   SITE_NAME                          416 non-null    object
#  3   PLOT_NO                            416 non-null    int64
#  4   FEATURE_ID                         413 non-null    object
#  5   LOCATION                           186 non-null    object
#  6   TYPE                               416 non-null    object
#  7   PRIM_MEAS                          416 non-null    float64
#  8   UNIT                               416 non-null    object
#  9   SITE_CODE                          416 non-null    object
#  10  FEAT_GP                            416 non-null    object
# ...
